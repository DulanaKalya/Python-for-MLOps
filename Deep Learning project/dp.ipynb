# %%
### Compare : Complete runs,choose a model, and deploy it to a REST API
"""
    In this quickstart, you will:
        -Run a hyperparameter sweep on a training script
        -Compare the results of the runs in the mlflow UI
        -Choose the best run and register it as a model
        -Deploy the model to a rest API
        -Build a container image suitable for deployment to a cloud platform"""
# Out:
# '\n    In this quickstart, you will:\n        -Run a hyperparameter sweep on a training script\n        -Compare the results of the runs in the mlflow UI\n        -Choose the best run and register it as a model\n        -Deploy the model to a rest API\n        -Build a container image suitable for deployment to a cloud platform'

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## Load the data set
data=pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into traning,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel() #ravel give 1 dimensional array
train_y,train_x
# Out:
# (array([6, 6, 5, ..., 6, 6, 8]),
#  array([[ 6.3 ,  0.25,  0.22, ...,  3.16,  0.5 , 10.5 ],
#         [ 7.8 ,  0.3 ,  0.29, ...,  3.16,  0.38,  9.  ],
#         [ 7.4 ,  0.38,  0.27, ...,  3.17,  0.43, 10.  ],
#         ...,
#         [ 7.6 ,  0.27,  0.52, ...,  3.02,  0.53, 11.4 ],
#         [ 6.3 ,  0.24,  0.29, ...,  3.17,  0.38, 10.6 ],
#         [ 8.1 ,  0.27,  0.35, ...,  3.22,  0.63, 10.4 ]]))

# %%
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

# %%
## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality2")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
#   0%|          | 0/4 [00:00<?, ?trial/s, best loss=?]
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 39s 868ms/step - loss: 38.1547 - root_mean_squared_error: 6.1769
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.1520 - root_mean_squared_error: 6.0949
# 34/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.1419 - root_mean_squared_error: 6.0107
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.4830 - root_mean_squared_error: 5.9550
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 35.2977 - root_mean_squared_error: 5.9392 - val_loss: 27.5073 - val_root_mean_squared_error: 5.2447
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 27.6491 - root_mean_squared_error: 5.2582
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.5789 - root_mean_squared_error: 5.1553
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0391 - root_mean_squared_error: 5.1024
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.4415 - root_mean_squared_error: 5.0430
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.4047 - root_mean_squared_error: 5.0393 - val_loss: 20.1139 - val_root_mean_squared_error: 4.4848
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 20.4670 - root_mean_squared_error: 4.5240
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5739 - root_mean_squared_error: 4.4241
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.3064 - root_mean_squared_error: 4.3936
# 34/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9429 - root_mean_squared_error: 4.3517
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.6173 - root_mean_squared_error: 4.3138
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.5603 - root_mean_squared_error: 4.3071 - val_loss: 14.6919 - val_root_mean_squared_error: 3.8330
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 15.4391 - root_mean_squared_error: 3.9293
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.5846 - root_mean_squared_error: 3.8187
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.6011 - root_mean_squared_error: 3.8209
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 33s 749ms/step - loss: 41.6468 - root_mean_squared_error: 6.4534
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.1559 - root_mean_squared_error: 6.3367
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.0561 - root_mean_squared_error: 6.3289
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 39.9091 - root_mean_squared_error: 6.3172 - val_loss: 38.2442 - val_root_mean_squared_error: 6.1842
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 37.6229 - root_mean_squared_error: 6.1338
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.8269 - root_mean_squared_error: 6.1504
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.8959 - root_mean_squared_error: 6.1560
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.6531 - root_mean_squared_error: 6.1362
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.5922 - root_mean_squared_error: 6.1312 - val_loss: 36.2269 - val_root_mean_squared_error: 6.0189
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 35.5125 - root_mean_squared_error: 5.9592
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.7686 - root_mean_squared_error: 5.9806
# 28/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.6954 - root_mean_squared_error: 5.9745
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.5822 - root_mean_squared_error: 5.9650
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.5401 - root_mean_squared_error: 5.9615 - val_loss: 34.3279 - val_root_mean_squared_error: 5.8590
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 35.6373 - root_mean_squared_error: 5.9697
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.2925 - root_mean_squared_error: 5.8559
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 32s 719ms/step - loss: 36.8767 - root_mean_squared_error: 6.0726
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.6310 - root_mean_squared_error: 6.0522
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.0664 - root_mean_squared_error: 6.0052
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 35.7733 - root_mean_squared_error: 5.9806 - val_loss: 31.7801 - val_root_mean_squared_error: 5.6374
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 33.3799 - root_mean_squared_error: 5.7775
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.2351 - root_mean_squared_error: 5.5879
# 28/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.8691 - root_mean_squared_error: 5.5551
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6907 - root_mean_squared_error: 5.5390
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.4362 - root_mean_squared_error: 5.5160
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.2561 - root_mean_squared_error: 5.4996 - val_loss: 26.6956 - val_root_mean_squared_error: 5.1668
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 26.0138 - root_mean_squared_error: 5.1004
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.5410 - root_mean_squared_error: 5.0537
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.1755 - root_mean_squared_error: 5.0173
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.0682 - root_mean_squared_error: 5.0065 - val_loss: 22.3994 - val_root_mean_squared_error: 4.7328
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 23.0173 - root_mean_squared_error: 4.7976
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.2481 - root_mean_squared_error: 4.7167
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 35s 790ms/step - loss: 31.8887 - root_mean_squared_error: 5.6470
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7022 - root_mean_squared_error: 3.7369
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.5825 - root_mean_squared_error: 3.1211
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 10.0817 - root_mean_squared_error: 3.0399 - val_loss: 1.5909 - val_root_mean_squared_error: 1.2613
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.3980 - root_mean_squared_error: 1.1824
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4593 - root_mean_squared_error: 1.2078
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4241 - root_mean_squared_error: 1.1931
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3994 - root_mean_squared_error: 1.1825 - val_loss: 1.1386 - val_root_mean_squared_error: 1.0670
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.0675 - root_mean_squared_error: 1.0332
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0140 - root_mean_squared_error: 1.0067
# 25/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0089 - root_mean_squared_error: 1.0043
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0028 - root_mean_squared_error: 1.0013
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9986 - root_mean_squared_error: 0.9992 - val_loss: 0.9315 - val_root_mean_squared_error: 0.9652
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8245 - root_mean_squared_error: 0.9080
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9380 - root_mean_squared_error: 0.9682
#
# 100%|██████████| 4/4 [01:24<00:00, 21.03s/trial, best loss: 0.9651522636413574]
# Best parameters: {'lr': 0.008482923815212392, 'momentum': 0.33741487112204593}
# Best eval rmse: 0.9651522636413574

# %%
with mlflow.start_run() as run:
    mlflow.keras.log_model(keras_model=model, name="model", signature=signature)
    model_uri = mlflow.get_artifact_uri("model")  # ✅ works inside the run
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 with mlflow.start_run() as run:
# ----> 2     mlflow.keras.log_model(keras_model=model, name="model", signature=signature)
#       3     model_uri = mlflow.get_artifact_uri("model")  # ✅ works inside the run
#
# NameError: name 'model' is not defined

# %%
## Inferencing

from mlflow.models import validate_serving_input


# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[29], line 15
#      12 serving_payload = convert_input_example_to_serving_input(test_x)
#      14 # Validate the serving payload works on the model
# ---> 15 validate_serving_input(model_uri, serving_payload)
#
# File ~/Desktop/Dulana/MLOps/lib/python3.12/site-packages/mlflow/models/utils.py:2004, in validate_serving_input(model_uri, serving_input)
#    2001 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    2003 try:
# -> 2004     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    2005     parsed_input = _parse_json_data(
#    2006         serving_input,
#    2007         pyfunc_model.metadata,
#    2008         pyfunc_model.metadata.get_input_schema(),
#    2009     )
#    2010     with _simulate_serving_environment():
#
# File ~/Desktop/Dulana/MLOps/lib/python3.12/site-packages/mlflow/tracing/provider.py:439, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     437 disable()
#     438 try:
# --> 439     is_func_called, result = True, f(*args, **kwargs)
#     440 finally:
#     441     enable()
#
# File ~/Desktop/Dulana/MLOps/lib/python3.12/site-packages/mlflow/pyfunc/__init__.py:1127, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1123         entity_list.append(Entity(job=job_entity))
#    1125     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1127 local_path = _download_artifact_from_uri(
#    1128     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1129 )
#    1131 if not suppress_warnings:
#    1132     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/Desktop/Dulana/MLOps/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:124, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri)
#     118     if isinstance(repo, ModelsArtifactRepository):
#     119         return repo.download_artifacts(
#     120             artifact_path=artifact_path,
#     121             dst_path=output_path,
#     122             lineage_header_info=lineage_header_info,
#     123         )
# --> 124     return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#     125 except Exception as e:
#     126     if artifact_uri.startswith("m-"):
#     127         # When a Model ID like string is passed, suggest using 'models:/{artifact_uri}' instead.
#
# File ~/Desktop/Dulana/MLOps/lib/python3.12/site-packages/mlflow/store/artifact/local_artifact_repo.py:92, in LocalArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#      90 local_artifact_path = os.path.join(self.artifact_dir, os.path.normpath(artifact_path))
#      91 if not os.path.exists(local_artifact_path):
# ---> 92     raise OSError(f"No such file or directory: '{local_artifact_path}'")
#      93 return os.path.abspath(local_artifact_path)
#
# OSError: No such file or directory: '/Users/nethsarani/Desktop/Dulana/Python-for-MLOps/Deep Learning project/mlruns/406637147908705388/0ee184f7f40745a6a7a30907638323ee/artifacts/model'
